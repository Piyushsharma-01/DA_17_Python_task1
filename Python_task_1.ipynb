# %% [markdown]
# #  1.  *Heading*
#
# ### Python Programming

# %% [markdown]
# ##### 2. *Paragraphs and Line Breaks*

# %% [markdown]
# This is Python Programming and this is my first paragraph

# %% [markdown]
# ##### 3. *Emphasis*

# %% [markdown]
# ##### * 3.1 *Italic*

# %% [markdown]
# *This is Italic using Asterik*

# %% [markdown]
# _This is Italic using underscore_

# %% [markdown]
# ##### * 3.2 **Bold**

# %% [markdown]
# **This is the Bold using double Asterik**

# %% [markdown]
# __This is the Bold using double Underscore__

# %% [markdown]
# ***This is Italic and Bold using triple Asterik***

# %% [markdown]
# ___This is Italic and Bold using triple Underscore___

# %% [markdown]
# ##### 4. *List*

# %% [markdown]
# ***Unordered List***

# %% [markdown]
# * Pyhton 1

# %% [markdown]
# * Python 2

# %% [markdown]
# * Python 3

# %% [markdown]
# ***Ordered List***

# %% [markdown]
# * 1.First
#   - 1.1.Second

# %% [markdown]
# * 2.Third

# %% [markdown]
# ##### 5. ***Links***

# %% [markdown]
# [ChatGPT](https://chat.openai.com)
# This is an inline link: [Oracle](https://www.oracle.com)

# %% [markdown]
# ##### 6. ***Images***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### 7. ***Code Blocks***

# %% [markdown]
# This is `inline code`.
#
# ```python
# def Hello_Jarvis():
#     print("Hello From Jarvis!)
#
# Hello_Jarvis()

# %% [markdown]
# #### 8. ***Block Quotes***

# %% [markdown]
# >A blockquote is a way to highlight quoted text
# >> Standard Blockquoates
# >> Nested Blockquoates

# %% [markdown]
# ##### 9. ***Horizontal***

# %% [markdown]
# ---
#
# ***
#
# ___

# %% [markdown]
# ___

# %% [markdown]
# ##### 10. ***Mathermatical Equations***

# %% [markdown]
# *The famous mmathematical equation* $E = mc^2$

# %% [markdown]
# *Complex Equations*
#
# $$
# \int_0\infty e^{-x^2}dx=\frac{\sqrt{\pi}}{2}
# $$
